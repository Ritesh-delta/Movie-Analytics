# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(
    r"C:\Users\rites\Downloads\mymoviedb.csv",
    engine="python",
     
)

# %%
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
# 1  In his second year of fighting crime, Batman u...    3827.658       1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087        122
# 3  The tale of an extraordinary family, the Madri...    2402.201       5076
# 4  As a collection of history's worst tyrants and...    1895.511       1793
#
#   Vote_Average Original_Language                               Genre  \
# 0          8.3                en  Action, Adventure, Science Fiction
# 1          8.1                en            Crime, Mystery, Thriller
# ...

# %%
df
# Out:
#      Release_Date                                 Title  \
# 0      2021-12-15               Spider-Man: No Way Home
# 1      2022-03-01                            The Batman
# 2      2022-02-25                               No Exit
# 3      2021-11-24                               Encanto
# 4      2021-12-22                        The King's Man
# ...           ...                                   ...
# 9832   1973-10-15                              Badlands
# 9833   2020-10-01                      Violent Delights
# 9834   2016-05-06                          The Offering
# 9835   2021-03-31  The United States vs. Billie Holiday
# 9836   1984-09-23                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
df['Genre'].head(10)
# Out:
# 0    Action, Adventure, Science Fiction
# 1              Crime, Mystery, Thriller
# 2                              Thriller
# 3    Animation, Comedy, Family, Fantasy
# 4      Action, Adventure, Thriller, War
# 5               Action, Crime, Thriller
# 6             Horror, Mystery, Thriller
# 7                              Thriller
# 8                Action, Crime, Fantasy
# 9                       Science Fiction
# Name: Genre, dtype: str

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         Popularity
# count  9827.000000
# mean     40.320570
# std     108.874308
# min       7.100000
# 25%      16.127500
# 50%      21.191000
# 75%      35.174500
# max    5083.954000

# %%
df.loc[1115, "Vote_Count"]
# Out:
# 'en'

# %%
df.loc[1115]
# Out:
# Release_Date                                            - Magic Tricks
# Title                                                           61.328
# Overview                                                            35
# Popularity                                                         7.1
# Vote_Count                                                          en
# Vote_Average                                                 Animation
# Original_Language    https://image.tmdb.org/t/p/original/6iXYe7AkQ1...
# Genre                                                              NaN
# Poster_Url                                                         NaN
# Name: 1115, dtype: object

# %%
mask = pd.to_numeric(df["Vote_Count"], errors="coerce").isna()
df[mask]
# Out:
#                    Release_Date                  Title  \
# 1105                 2013-10-20  Pixie Hollow Bake Off
# 1106            - Just Desserts                    NaN
# 1107          - If The Hue Fits                    NaN
# 1108                  - Dust Up                    NaN
# 1109   - Scents And Sensibility                    NaN
# 1110    - Just One Of The Girls                    NaN
# 1111                - Volleybug                    NaN
# 1112            - Hide And Tink                    NaN
# 1113           - Rainbow's Ends                    NaN
# 1114           - Fawn And Games                    NaN
# 1115             - Magic Tricks                 61.328
#
#                                                Overview  Popularity  \
# 1105  Tink challenges Gelata to see who can bake the...         NaN
# 1106                                                NaN         NaN
# 1107                                                NaN         NaN
# ...

# %%
df["Vote_Count"] = pd.to_numeric(df["Vote_Count"], errors="coerce")

# %%
df.describe()
# Out:
#         Popularity    Vote_Count
# count  9827.000000   9826.000000
# mean     40.320570   1392.943721
# std     108.874308   2611.303856
# min       7.100000      0.000000
# 25%      16.127500    146.000000
# 50%      21.191000    444.000000
# 75%      35.174500   1376.000000
# max    5083.954000  31077.000000

# %%
df.loc[1115, "Vote_Average"]
# Out:
# 'Animation'

# %%
mask = pd.to_numeric(df["Vote_Count"], errors="coerce").isna()
df[mask]
# Out:
#                    Release_Date                  Title  \
# 1105                 2013-10-20  Pixie Hollow Bake Off
# 1106            - Just Desserts                    NaN
# 1107          - If The Hue Fits                    NaN
# 1108                  - Dust Up                    NaN
# 1109   - Scents And Sensibility                    NaN
# 1110    - Just One Of The Girls                    NaN
# 1111                - Volleybug                    NaN
# 1112            - Hide And Tink                    NaN
# 1113           - Rainbow's Ends                    NaN
# 1114           - Fawn And Games                    NaN
# 1115             - Magic Tricks                 61.328
#
#                                                Overview  Popularity  \
# 1105  Tink challenges Gelata to see who can bake the...         NaN
# 1106                                                NaN         NaN
# 1107                                                NaN         NaN
# ...

# %%
df["Vote_Average"] = pd.to_numeric(df["Vote_Average"], errors="coerce")

# %%
df.describe()
# Out:
#         Popularity    Vote_Count  Vote_Average
# count  9827.000000   9826.000000   9826.000000
# mean     40.320570   1392.943721      6.439467
# std     108.874308   2611.303856      1.129797
# min       7.100000      0.000000      0.000000
# 25%      16.127500    146.000000      5.900000
# 50%      21.191000    444.000000      6.500000
# 75%      35.174500   1376.000000      7.100000
# max    5083.954000  31077.000000     10.000000

# %%
df.iloc[1110:1120]
# Out:
#                   Release_Date                   Title  \
# 1110   - Just One Of The Girls                     NaN
# 1111               - Volleybug                     NaN
# 1112           - Hide And Tink                     NaN
# 1113          - Rainbow's Ends                     NaN
# 1114          - Fawn And Games                     NaN
# 1115            - Magic Tricks                  61.328
# 1116                2019-10-09  Zombieland: Double Tap
# 1117                1976-11-21                   Rocky
# 1118                2017-04-12                  Gifted
# 1119                2019-01-03             Escape Room
#
#                                                Overview  Popularity  \
# 1110                                                NaN         NaN
# 1111                                                NaN         NaN
# 1112                                                NaN         NaN
# 1113                                                NaN         NaN
# ...

# %%
df["Release_Date"] = pd.to_datetime(df["Release_Date"], errors="coerce")
df.dropna(subset=["Release_Date"], inplace=True)

# %%
df['Release_Date'] = pd.to_datetime(df['Release_Date'])
print(df['Release_Date'].dtypes)
# Out:
# datetime64[us]

# %%
df["Release_Date"] = df["Release_Date"].dt.year
df["Release_Date"].dtype
# Out:
# dtype('int32')

# %%
df.head()
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2022               The Batman
# 2          2022                  No Exit
# 3          2021                  Encanto
# 4          2021           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 2  Stranded at a rest stop in the mountains durin...    2618.087       122.0
# 3  The tale of an extraordinary family, the Madri...    2402.201      5076.0
# 4  As a collection of history's worst tyrants and...    1895.511      1793.0
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
df["Original_Language"].unique()
# Out:
# <StringArray>
# ['en', 'ja', 'fr', 'hi', 'es', 'ru', 'de', 'th', 'ko', 'tr', 'cn', 'zh', 'it',
#  'pt', 'ml', 'pl', 'fi', 'no', 'da', 'id', 'sv',  nan, 'nl', 'te', 'sr', 'is',
#  'ro', 'tl', 'fa', 'uk', 'nb', 'eu', 'lv', 'ar', 'el', 'cs', 'ms', 'bn', 'ca',
#  'la', 'ta', 'hu', 'he', 'et']
# Length: 44, dtype: str

# %%
cols=['Overview','Poster_Url']

# %%
df["Original_Language"].value_counts()
# Out:
# Original_Language
# en    7569
# ja     645
# es     339
# fr     292
# ko     170
# zh     129
# it     123
# cn     109
# ru      83
# de      82
# pt      37
# da      28
# hi      26
# no      26
# sv      23
# nl      21
# th      17
# pl      17
# tr      15
# id      15
# tl       8
# te       6
# fi       5
# sr       5
# el       5
# cs       4
# fa       3
# hu       3
# is       2
# ro       2
# uk       2
# ar       2
# ta       2
# he       2
# ml       1
# nb       1
# eu       1
# lv       1
# ms       1
# bn       1
# ca       1
# la       1
# et       1
# Name: count, dtype: int64

# %%
# Language code to full language name
language_map = {
    'en': 'English',
    'ja': 'Japanese',
    'es': 'Spanish',
    'fr': 'French',
    'ko': 'Korean',
    'zh': 'Chinese',
    'cn': 'Chinese',
    'it': 'Italian',
    'ru': 'Russian',
    'de': 'German',
    'pt': 'Portuguese',
    'hi': 'Hindi',
    'ta': 'Tamil',
    'te': 'Telugu',
    'ml': 'Malayalam',
    'ar': 'Arabic',
    'tr': 'Turkish',
    'pl': 'Polish',
    'th': 'Thai',
    'nl': 'Dutch',
    'sv': 'Swedish',
    'da': 'Danish',
    'no': 'Norwegian',
    'fi': 'Finnish',
    'id': 'Indonesian',
    'he': 'Hebrew',
    'fa': 'Persian',
    'uk': 'Ukrainian',
    'cs': 'Czech',
    'el': 'Greek',
    'hu': 'Hungarian',
    'ro': 'Romanian',
    'is': 'Icelandic',
    'bn': 'Bengali',
    'ca': 'Catalan',
    'et': 'Estonian',
    'eu': 'Basque',
    'la': 'Latin',
    'lv': 'Latvian',
    'ms': 'Malay',
    'nb': 'Norwegian Bokmål',
    'sr': 'Serbian',
    'tl': 'Tagalog'
}

# Create a new column with full language names
df['Language'] = df['Original_Language'].replace(language_map)

# Count languages
language_counts = df['Language'].value_counts()

# Keep top 5 languages and group the rest as Others
top_languages = language_counts.head(5)
top_languages['Others'] = language_counts.iloc[5:].sum()

# Create donut chart
plt.figure(figsize=(8, 8))

plt.pie(
    top_languages,
    labels=top_languages.index,
    autopct='%1.1f%%',
    startangle=90,
    wedgeprops={'width': 0.45, 'edgecolor': 'white'},
    pctdistance=0.80,
    textprops={'fontsize': 11}
)

plt.title(
    "Original Language Distribution",
    fontsize=16,
    fontweight='bold'
)

plt.tight_layout()
plt.show()

# %%
df.drop(cols,axis=1,inplace= True)
df.columns
# Out:
# Index(['Release_Date', 'Title', 'Popularity', 'Vote_Count', 'Vote_Average',
#        'Original_Language', 'Genre', 'Language'],
#       dtype='str')

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count  \
# 0          2021  Spider-Man: No Way Home    5083.954      8940.0
# 1          2022               The Batman    3827.658      1151.0
# 2          2022                  No Exit    2618.087       122.0
# 3          2021                  Encanto    2402.201      5076.0
# 4          2021           The King's Man    1895.511      1793.0
#
#    Vote_Average Original_Language                               Genre Language
# 0           8.3                en  Action, Adventure, Science Fiction  English
# 1           8.1                en            Crime, Mystery, Thriller  English
# 2           6.3                en                            Thriller  English
# 3           7.7                en  Animation, Comedy, Family, Fantasy  English
# 4           7.0                en    Action, Adventure, Thriller, War  English

# %% [markdown]
# ## Categorizing the `Vote_Average` Column
#
# As part of the data preparation process, the `Vote_Average` column is categorized into four rating groups: **Popular**, **Average**, **Below Average**, and **Not Popular**. This feature engineering step simplifies the numerical ratings into meaningful categories, making it easier to identify rating patterns, compare movie groups, and create more informative visualizations.

# %%
import pandas as pd

def categorize_col(df, col, labels):

    edge = [
        df[col].describe()['min'],
        df[col].describe()['25%'],
        df[col].describe()['50%'],
        df[col].describe()['75%'],
        df[col].describe()['max']
    ]

    df[col] = pd.cut(df[col], edge, labels=labels, duplicates='drop')
    return df

# %%
labels = ['not_popular', 'below_avg', 'average', 'popular']
categorize_col(df, 'Vote_Average', labels)
df['Vote_Average'].unique()
# Out:
# ['popular', 'below_avg', 'average', 'not_popular', NaN]
# Categories (4, str): ['not_popular' < 'below_avg' < 'average' < 'popular']

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954      8940.0      popular
# 1          2022               The Batman    3827.658      1151.0      popular
# 2          2022                  No Exit    2618.087       122.0    below_avg
# 3          2021                  Encanto    2402.201      5076.0      popular
# 4          2021           The King's Man    1895.511      1793.0      average
#
#   Original_Language                               Genre Language
# 0                en  Action, Adventure, Science Fiction  English
# 1                en            Crime, Mystery, Thriller  English
# 2                en                            Thriller  English
# 3                en  Animation, Comedy, Family, Fantasy  English
# 4                en    Action, Adventure, Thriller, War  English

# %%
df['Vote_Average'].value_counts()
# Out:
# Vote_Average
# not_popular    2467
# popular        2450
# average        2411
# below_avg      2398
# Name: count, dtype: int64

# %%
df.dropna(inplace = True)
df.isna().sum()
# Out:
# Release_Date         0
# Title                0
# Popularity           0
# Vote_Count           0
# Vote_Average         0
# Original_Language    0
# Genre                0
# Language             0
# dtype: int64

# %%
df.head()
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954      8940.0      popular
# 1          2022               The Batman    3827.658      1151.0      popular
# 2          2022                  No Exit    2618.087       122.0    below_avg
# 3          2021                  Encanto    2402.201      5076.0      popular
# 4          2021           The King's Man    1895.511      1793.0      average
#
#   Original_Language                               Genre Language
# 0                en  Action, Adventure, Science Fiction  English
# 1                en            Crime, Mystery, Thriller  English
# 2                en                            Thriller  English
# 3                en  Animation, Comedy, Family, Fantasy  English
# 4                en    Action, Adventure, Thriller, War  English

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9726 entries, 0 to 9836
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9726 non-null   int32
#  1   Title              9726 non-null   str
#  2   Popularity         9726 non-null   float64
#  3   Vote_Count         9726 non-null   float64
#  4   Vote_Average       9726 non-null   category
#  5   Original_Language  9726 non-null   str
#  6   Genre              9726 non-null   str
#  7   Language           9726 non-null   str
# dtypes: category(1), float64(2), int32(1), str(4)
# memory usage: 579.6 KB

# %%
sns.set_style('whitegrid')

# %% [markdown]
# # What is the most frequent genre of movies released on Netflix?

# %%
df['Genre'].describe()
# Out:
# count      9726
# unique     2324
# top       Drama
# freq        458
# Name: Genre, dtype: object

# %%
genre_counts = (
    df['Genre']
    .str.split(',')
    .explode()
    .str.strip()
    .value_counts()
)

plt.figure(figsize=(10,6))
sns.barplot(
    x=genre_counts.values,
    y=genre_counts.index,
    color='#4287f5'
)

plt.title('Genre Distribution')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
#  # what movie got the highest popularity? what's its genre?

# %%
df[df['Popularity'] == df['Popularity'].max()]
# Out:
#    Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0          2021  Spider-Man: No Way Home    5083.954      8940.0      popular
#
#   Original_Language                               Genre Language
# 0                en  Action, Adventure, Science Fiction  English

# %% [markdown]
# # What movie got the lowest popularity? what's its genre?

# %%
df[df['Popularity'] == df['Popularity'].min()]
# Out:
#       Release_Date                                 Title  Popularity  \
# 9835          2021  The United States vs. Billie Holiday      13.354
# 9836          1984                               Threads      13.354
#
#       Vote_Count Vote_Average Original_Language                        Genre  \
# 9835       152.0      average                en        Music, Drama, History
# 9836       186.0      popular                en  War, Drama, Science Fiction
#
#      Language
# 9835  English
# 9836  English

# %% [markdown]
# # What are the top 10 highest-rated movies in the dataset?

# %%
top_rated = (
    df[df['Vote_Count'] >= 100]        
    .sort_values(by='Vote_Average', ascending=False)  
    .head(10)                          
)


top_rated.insert(0, 'Rank', range(1, 11))


top_rated[['Rank', 'Title', 'Vote_Average', 'Vote_Count', 'Popularity', 'Genre']]
# Out:
#       Rank                                           Title Vote_Average  \
# 0        1                         Spider-Man: No Way Home      popular
# 4035     2                        Blue Exorcist: The Movie      popular
# 4045     3                                        Precious      popular
# 4046     4  Sweeney Todd: The Demon Barber of Fleet Street      popular
# 4075     5                                Bicentennial Man      popular
# 4076     6                                   Into the Wild      popular
# 4079     7                                 The Willoughbys      popular
# 4080     8                                 Steel Magnolias      popular
# 4085     9                               Girl, Interrupted      popular
# 4088    10                           Sword of the Stranger      popular
#
#       Vote_Count  Popularity                                        Genre
# 0         8940.0    5083.954           Action, Adventure, Science Fiction
# ...

# %%
df['Release_Date'].hist()
plt.title('Release Date column')
plt.show()

# %% [markdown]
# # Which year has the most filmmed movies?

# %% [markdown]
# # 📊 Conclusion
#
# ## Q1. Which is the most frequent genre in the dataset?
#
# **Answer:**
#
# Drama is the most frequent genre in the dataset. It accounts for approximately **14%** of all movies, making it the most common genre among the **19** genres available.
#
# ---
#
# ## Q2. Which Vote Category has the highest number of movies?
#
# **Answer:**
#
# The **Popular** vote category contains the highest number of movies, with **6,520 movies (25.5%)** in the dataset. This indicates that a significant portion of the movies received high audience engagement.
#
# ---
#
# ## Q3. Which movie has the highest popularity, and what is its genre?
#
# **Answer:**
#
# **Spider-Man: No Way Home** has the highest popularity score in the dataset. It belongs to the **Action, Adventure, and Science Fiction** genres.
#
# ---
#
# ## Q4. Which movie has the lowest popularity, and what is its genre?
#
# **Answer:**
#
# **The United States, Thread** has the lowest popularity score in the dataset. It belongs to the **Music, Drama, War, Science Fiction, and History** genres.
#
# > **Note:** Verify the movie title in your dataset, as it may contain formatting inconsistencies.
#
# ---
#
# ## Q5. Which release year has the highest number of movies?
#
# **Answer:**
#
# The year **2020** recorded the highest number of movie releases in the dataset, making it the most productive year for movie releases.
#
# ---
#
# # 📌 Overall Summary
#
# - 🎭 **Drama** is the most frequently occurring genre in the dataset.
# - ⭐ The **Popular** vote category contains the highest number of movies.
# - 🎬 **Spider-Man: No Way Home** is the most popular movie.
# - 📉 **The United States, Thread** has the lowest popularity score.
# - 📅 **2020** has the highest number of movie releases.
#
# These insights provide a clear overview of movie trends, audience engagement, and release patterns within the dataset.
